# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd
import cv2
from scipy import ndimage
import cv2 as cv
import urllib.request
import matplotlib.pyplot as plt
# construct the argument parse and parse the arguments

# %%
coin1 = Coin_Detection("coin8.jpg")
img,coins = coin1.Watershed_Detection(0.7)
img,coins = coin1.HoughCircles_Detection(1,40)
img,coins = coin1.with_Canny_And_Contours()
# Out:
# 				 coin8
# ********************************************************************************
# Method:  WaterShed
# 4 No of Coins Present in Image
# ********************************************************************************
# ********************************************************************************
# Method:  Hough Circles
# 7 No of Coins Present in Image
# ********************************************************************************
# ********************************************************************************
# Method:  Canny and Contours
# 8 No of Coins Present in Image
# ********************************************************************************

# %%
print(max(set(l),key = l.count))
l.clear()
# Out:
# 8
